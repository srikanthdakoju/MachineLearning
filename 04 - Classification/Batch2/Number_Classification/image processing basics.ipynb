# %% [markdown]
# # Image processing basic

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

# %% [markdown]
# **Loading Image **

# %%
img = cv2.imread('image1.jpg')

# %%
img.shape
# Out:
# (400, 500, 3)

# %% [markdown]
# row , col , depth

# %%
plt.imshow(img)
plt.show()
# red green and blue
# python blue green and red

# %%
# splitting 
b, g ,r = cv2.split(img)
img_new = cv2.merge((r , g ,b))
plt.imshow(img_new)

# %% [markdown]
# **Convert color image into grayscale **

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (400, 500)

# %%
plt.imshow(gray, cmap = 'gray')

# %% [markdown]
#  8 bit

# %%
gray
# Out:
# array([[139, 138, 137, ...,  87,  87,  87],
#        [138, 137, 136, ...,  87,  87,  87],
#        [136, 136, 135, ...,  87,  87,  87],
#        ...,
#        [ 27,  27,  27, ..., 253, 253, 253],
#        [ 27,  27,  28, ..., 253, 253, 253],
#        [ 27,  27,  28, ..., 253, 253, 253]], dtype=uint8)

# %% [markdown]
# **Converting gray scale image into binary (threshold)**

# %%
ret , thresh1 = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
ret , thresh2 = cv2.threshold(gray,127,255,cv2.THRESH_BINARY_INV)

# %%
plt.subplot(1,2,1)
plt.imshow(thresh1,cmap = 'gray')
plt.subplot(1,2,2)
plt.imshow(thresh2,cmap = 'gray')
plt.show()
