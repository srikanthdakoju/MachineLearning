# %% [markdown]
# # Visualizing Information

# %%
# importing required libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %% [markdown]
# Analysing "Data Flick's solutions private limited"
#
# importing data

# %%
no_units = pd.read_excel('./data/df_genre_units.xlsx') # reading data

# %%
no_units = no_units.set_index('Genre')

# %%
no_units
# Out:
#           Units sold
# Genre
# Sports         27500
# Startegy       11500
# Action          6000
# Shooter         3500
# Other           1500

# %%
plt.figure(figsize=(6,6))
no_units['Units sold'].plot.pie(autopct='%.0f%%')
plt.show()

# %% [markdown]
# **Visualizing statisfied customers**

# %%
satisfied = pd.read_excel('./data/statistics/df_statisfied.xlsx') # reading data
satisfied = satisfied.set_index('Genre')
satisfied
# Out:
#           Satisfied
# Genre
# Sports           99
# Startegy         90
# Action           85
# Shooter          95
# Other            85

# %%
plt.figure(figsize=(6,6))
satisfied['Satisfied'].plot.pie(autopct='%.0f%%')

# %% [markdown]
# **Bar plot **
# > vertical plot

# %%
plt.figure(figsize=(10,5))
satisfied['Satisfied'].plot.bar()
plt.ylabel('Statified customers in %')
plt.show()

# %% [markdown]
# > horizontal plot

# %%
plt.figure(figsize=(10,5))
satisfied['Satisfied'].plot.barh()
plt.xlabel('Statified customers in %')
plt.show()

# %%
satisfied['unsatisfied']  = 100-satisfied['Satisfied']

# %%
satisfied
# Out:
#           Satisfied  unsatisfied
# Genre
# Sports           99            1
# Startegy         90           10
# Action           85           15
# Shooter          95            5
# Other            85           15

# %% [markdown]
# Split Category bar plot
# > Vertical

# %%
plt.figure(figsize=(10,5))
satisfied.plot.bar()
plt.ylabel('Statified customers in %')
plt.show()

# %% [markdown]
# > Horizontal

# %%
plt.figure(figsize=(15,7))
satisfied.plot.barh()
plt.xlabel('Statified customers in %')
plt.show()

# %% [markdown]
# **Split Category bar plot**
# > Vertical

# %%
plt.figure(figsize=(10,5))
satisfied.plot.bar(stacked = True)
plt.ylabel('Statified customers in %')
plt.show()

# %%
plt.figure(figsize=(10,5))
satisfied.plot.barh(stacked = True)
plt.xlabel('Statified customers in %')
plt.show()

# %% [markdown]
#  **Execrise**
#
# The CEO needs another chart for the keynote presentation.
# Here’s the data; see if you can sketch the bar chart
# ![image.png](attachment:image.png)

# %%
sales_unit = pd.read_excel('./data/statistics/df_salesunit.xlsx')
sales = pd.read_excel('./data/statistics/df_sales.xlsx')
sales_unit = sales_unit.set_index('Continent ')
sales_unit
# Out:
#                Sales  (unit)
# Continent
# North America           1500
# South America            500
# Europe                  1500
# Asia                    2000
# Oceania                 1000
# Africa                   500
# Antarctica                 1

# %%
sales = sales.set_index('Genre')
sales
# Out:
#           2016 (sales)  2017 (sales)
# Genre
# Sports           14000         27500
# Strategy         15000         12500
# Action            7000          6000
# Shooter           5000          3500

# %% [markdown]
# **Charts**

# %%
sales_unit['Sales  (unit)'].plot.pie()
plt.title('Pie chart')
# bar chart
sales_unit.plot.bar()
plt.title('bar chart')

# bar chart
sales_unit.plot.barh()
plt.title('horizontal bar chart')
#plt.show()
# Out:
# Text(0.5,1,'horizontal bar chart')

# %% [markdown]
# **Sales**

# %%
sales.keys()
# Out:
# Index([u'2016 (sales)', u'2017 (sales)'], dtype='object')

# %%
# %matplotlib inline

# %%
# bar chart
sales.plot.bar()
plt.title('bar chart')

# bar chart
sales.plot.barh()
plt.title('horizontal bar chart')
#plt.show()
# Out:
# Text(0.5,1,'horizontal bar chart')

# %% [markdown]
# **Excerise - 2**

# %%
score = pd.read_excel('./data/statistics/df_scores.xlsx')
score.keys()
# Out:
# Index([u'Scores ', u'Frequency'], dtype='object')

# %%
score = score.set_index('Scores ')
score
# Out:
#          Frequency
# Scores
# 0-199            5
# 200-399         29
# 400-599         56
# 600-799         17
# 800-999          3

# %% [markdown]
# **Charts**

# %%
score['Frequency'].plot.pie()
plt.title('Pie chart')
# bar chart
score.plot.bar()
plt.title('bar chart')

# bar chart
score.plot.barh()
plt.title('horizontal bar chart')
#plt.show()
# Out:
# Text(0.5,1,'horizontal bar chart')
