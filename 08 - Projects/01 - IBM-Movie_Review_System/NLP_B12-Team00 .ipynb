# %% [markdown]
# # MOVIE REVIEW SYSTEM
#
# Team Members:
#
# Name1, Name 2

# %% [markdown]
# **Step -1 : importing libraries**

# %%
import numpy as np
import pandas as pd
import nltk # natural langurage tool kit
import re # regualr expressions
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %% [markdown]
# significance of stopwords:

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/dsxuser/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop = stopwords.words('english')
stop.remove('not') # in sentiment analyis this not stop word
stop.append('srikanth') # you customize stopwords like this

# %% [markdown]
# **Step -2: Loading dataset**

# %%
import sys
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_5022ebd052cb493da82d0f09840119df = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='DMMNhzi-atYLYCQMpwLK7mxFvl-fRNLO3_JeYzYiBysy',
    ibm_auth_endpoint="https://iam.eu-gb.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about your possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/
streaming_body_2 = client_5022ebd052cb493da82d0f09840119df.get_object(Bucket='batch2-donotdelete-pr-jqe78ba82u2s6i', Key='train_new.tsv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(streaming_body_2, "__iter__"): streaming_body_2.__iter__ = types.MethodType( __iter__, streaming_body_2 )

# %%
dataset = pd.read_csv(streaming_body_2,delimiter='\t')
dataset.head()
# Out:
#    Unnamed: 0  PhraseId  SentenceId  \
# 0           0         1           1
# 1          63        64           2
# 2          81        82           3
# 3         116       117           4
# 4         156       157           5
#
#                                               Phrase  Sentiment
# 0  A series of escapades demonstrating the adage ...          1
# 1  This quiet , introspective and entertaining in...          4
# 2  Even fans of Ismail Merchant 's work , I suspe...          1
# 3  A positively thrilling combination of ethnogra...          3
# 4  Aggressive self-glorification and a manipulati...          1

# %% [markdown]
# **Step - 3 : Cleaning text , steming, removing stopwords**

# %%
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2627 entries, 0 to 2626
# Data columns (total 5 columns):
# Unnamed: 0    2627 non-null int64
# PhraseId      2627 non-null int64
# SentenceId    2627 non-null int64
# Phrase        2627 non-null object
# Sentiment     2627 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 102.7+ KB
# None

# %% [markdown]
# **Working with text**

# %%
text = dataset['Phrase']

# %%
data = []
for i in range(len(dataset)):
    review = text[i] # change into i
    # step -1: converting letter into lower case
    review = review.lower()
    # step -2: removing special character and numerics
    review = re.sub('[^a-z]',' ',review)
    # step -3: convert sentence into list of words -> tokens
    review = review.split()
    # step -4: Stemming(extracting root word) and removing stopwords
    ps = PorterStemmer()
    review = [ps.stem(word) for word in review if not word in set(stop)]
    review = ' '.join(review)# step 5: joining words 
    data.append(review) # appending data

# %% [markdown]
# **Step- 3 : Bag of word model**
#
# - CountVectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

# %%
# Converting words into numbers (Word Embedding)
X = cv.fit_transform(data).toarray() # all the clean stentence are in my data
y = dataset['Sentiment'].values

# %%
print(len(cv.get_feature_names()))
print(cv.get_feature_names())
# Out:
# 6078
# ['aaliyah', 'abandon', 'abel', 'abhorr', 'abil', 'abl', 'abort', 'abound', 'abridg', 'abrupt', 'absolut', 'absorb', 'absorpt', 'abstract', 'absurd', 'absurdist', 'absurdli', 'abund', 'abus', 'academ', 'academi', 'accent', 'accept', 'access', 'accompani', 'accomplish', 'account', 'accumul', 'accur', 'ach', 'achero', 'achiev', 'achingli', 'acid', 'ackerman', 'acknowledg', 'acquaint', 'acquir', 'acrid', 'across', 'act', 'action', 'activ', 'activist', 'actor', 'actorish', 'actress', 'actual', 'acumen', 'acut', 'ad', 'adag', 'adam', 'adapt', 'add', 'addict', 'addit', 'address', 'adequ', 'adject', 'adjust', 'admir', 'admiss', 'admit', 'admittedli', 'adolesc', 'ador', 'adren', 'adrenalin', 'adrien', 'adrift', 'adult', 'advanc', 'advantag', 'adventu', 'adventur', 'advert', 'advic', 'aesop', 'aesthet', 'affabl', 'affair', 'affect', 'affection', 'affirm', 'affleck', 'aficionado', 'afloat', 'african', 'afterlif', 'afternoon', 'aftertast', 'age', 'agenda', 'agent', 'ager', 'aggress', 'agil', 'agit', 'ago', 'agre', 'ah', 'ahead', 'ahem', 'ai', 'aid', 'aim', 'aimless', 'air', 'airhead', 'airi', 'airless', 'akin', 'ala', 'alabama', 'alacr', 'aladdin', 'alain', 'albeit', 'alert', 'alexand', 'alfr', 'alia', 'alic', 'alien', 'alik', 'aliv', 'allegedli', 'allegori', 'allen', 'alli', 'allow', 'allur', 'allus', 'almost', 'alon', 'along', 'aloof', 'alreadi', 'also', 'alt', 'altar', 'alter', 'altern', 'although', 'altogeth', 'alway', 'amaro', 'amass', 'amateurish', 'amateurishli', 'amaz', 'amazingli', 'ambigu', 'ambit', 'ambiti', 'amc', 'america', 'american', 'ami', 'amiabl', 'amid', 'amini', 'amir', 'amish', 'amo', 'among', 'amount', 'amour', 'amus', 'amusedli', 'anachronist', 'anakin', 'analyt', 'analyz', 'anchor', 'anderson', 'andi', 'andrei', 'anem', 'angel', 'angl', 'angri', 'angst', 'anguish', 'anim', 'animatron', 'ankl', 'ann', 'annex', 'annoy', 'anomi', 'anonym', 'anoth', 'answer', 'ant', 'antholog', 'anthoni', 'anthropolog', 'anthropomorph', 'anti', 'antic', 'anticip', 'anton', 'antonia', 'antwon', 'anyon', 'anyplac', 'anyth', 'anyway', 'anywher', 'apart', 'apartheid', 'ape', 'apex', 'appar', 'appeal', 'appear', 'appet', 'appetit', 'appl', 'appli', 'appoint', 'appreci', 'approach', 'appropri', 'apt', 'ararat', 'arbitrarili', 'arc', 'arcan', 'arch', 'archetyp', 'architectur', 'ardent', 'ardor', 'arduou', 'area', 'argento', 'argu', 'aristocraci', 'arm', 'armenian', 'arni', 'arnold', 'around', 'arriv', 'art', 'arthur', 'arti', 'articul', 'artific', 'artifici', 'artist', 'artsi', 'artsploit', 'artwork', 'ascertain', 'ash', 'asham', 'asian', 'asiaphil', 'asid', 'ask', 'asleep', 'asparagu', 'aspect', 'aspir', 'assassin', 'assault', 'assaya', 'assembl', 'assess', 'asset', 'assign', 'assimil', 'associ', 'assum', 'assumpt', 'assur', 'astonish', 'astonishingli', 'astound', 'astoundingli', 'astray', 'astring', 'astronaut', 'astut', 'asylum', 'athletic', 'atmospher', 'atop', 'atroci', 'attach', 'attack', 'attal', 'attempt', 'attend', 'attent', 'attitud', 'attract', 'attribut', 'audac', 'audaci', 'audiard', 'audienc', 'aussi', 'auster', 'austin', 'australian', 'auteuil', 'auteur', 'authent', 'author', 'autist', 'auto', 'autobiograph', 'autocritiqu', 'automat', 'autopsi', 'avail', 'avant', 'avari', 'aveng', 'averag', 'avers', 'avert', 'avoid', 'aw', 'awak', 'awaken', 'awar', 'award', 'away', 'awkward', 'awkwardli', 'ayala', 'ayurveda', 'baader', 'babak', 'babbitt', 'babi', 'back', 'backdrop', 'background', 'backmask', 'backward', 'backwat', 'bad', 'badder', 'badli', 'baffl', 'bag', 'bagatel', 'baggag', 'bai', 'bake', 'balanc', 'bald', 'bale', 'balk', 'ball', 'ballerina', 'ballesta', 'ballet', 'ballot', 'baloney', 'bam', 'banal', 'band', 'bank', 'banter', 'banzai', 'bar', 'baran', 'barb', 'barbar', 'barbarian', 'barbera', 'barbershop', 'bard', 'bare', 'barlow', 'barn', 'barrel', 'barri', 'barrier', 'barrow', 'bart', 'bartlebi', 'bartlett', 'base', 'basebal', 'basest', 'bash', 'basi', 'basic', 'basketbal', 'bat', 'bathtub', 'batman', 'battl', 'bawdi', 'be' ...

# %% [markdown]
# **Step -4: Spliting data into traning and testing set**

# %%
from sklearn.cross_validation import train_test_split
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size = 0.2,
                                                   random_state =0 )

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((2101, 6078), (526, 6078), (2101,), (526,))

# %% [markdown]
# ** Step -5: Building Machine Learning Mode -> MultinomialNB, GaussianNB**

# %%
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
model_log = LogisticRegression(C = 10.0)
model_knn = KNeighborsClassifier(n_neighbors=3)
model_svm = SVC(C = 10.0,probability=True) 
model_dt = DecisionTreeClassifier()
model_rf = RandomForestClassifier(n_estimators=100)
model_nb = MultinomialNB(alpha = 1)

# %%
model_nb = MultinomialNB(alpha = 1.5)

# %% [markdown]
# *traning*

# %%
model_log.fit(x_train, y_train) # training model
model_knn.fit(x_train, y_train) # training model
model_svm.fit(x_train, y_train) # training model
model_dt.fit(x_train, y_train) # training model
model_rf.fit(x_train, y_train) # training model
# Out:
# MultinomialNB(alpha=1, class_prior=None, fit_prior=True)

# %%
model_nb.fit(x_train, y_train) # traning model
# Out:
# MultinomialNB(alpha=1.5, class_prior=None, fit_prior=True)

# %% [markdown]
# **Step - 6 : Evaluation**

# %%
y_pred_log = model_log.predict(x_test) # we use this for evaluation
y_pred_knn = model_knn.predict(x_test) # we use this for evaluation
y_pred_svm = model_svm.predict(x_test) # we use this for evaluation
y_pred_dt = model_dt.predict(x_test) # we use this for evaluation
y_pred_rf = model_rf.predict(x_test) # we use this for evaluation

# %%
y_pred_nb = model_nb.predict(x_test) # we use this for evaluation

# %% [markdown]
# *classification metric*

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
cm_log = confusion_matrix(y_test, y_pred_log) # confusion matrix
cm_knn = confusion_matrix(y_test, y_pred_knn) # confusion matrix
cm_svm = confusion_matrix(y_test, y_pred_svm) # confusion matrix
cm_dt = confusion_matrix(y_test, y_pred_dt) # confusion matrix
cm_rf = confusion_matrix(y_test, y_pred_rf) # confusion matrix
cm_nb = confusion_matrix(y_test, y_pred_nb) # confusion matrix


cr_log = classification_report(y_test, y_pred_log) # classification report
cr_knn = classification_report(y_test, y_pred_knn) # classification report
cr_svm = classification_report(y_test, y_pred_svm) # classification report
cr_dt = classification_report(y_test, y_pred_dt) # classification report
cr_rf = classification_report(y_test, y_pred_rf) # classification report
cr_nb = classification_report(y_test, y_pred_nb) # classification report

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
sns.heatmap(cm_log,annot=True,cbar=None,cmap = 'summer')
plt.title('Logistic Regression')
plt.show()
sns.heatmap(cm_knn,annot=True,cbar=None,cmap = 'spring')
plt.title('K Nearest Neighbour')
plt.show()
sns.heatmap(cm_svm,annot=True,cbar=None,cmap = 'winter')
plt.title('Support Vector Machine')
plt.show()
sns.heatmap(cm_dt,annot=True,cbar=None,cmap = 'cool')
plt.title('Desicion Tree')
plt.show()
sns.heatmap(cm_rf,annot=True,cbar=None,cmap = 'autumn')
plt.title('Random Forest')
plt.show()
sns.heatmap(cm_nb,annot=True,cbar=None,cmap = 'Set1')
plt.title('Multinomial Navie Bayes')
plt.show()

# %%
print('='*20+'Logistic Regression'+'='*20)
print(cr_log)
print('='*20+'KNearest Neighbour'+'='*20)
print(cr_knn)
print('='*20+'Support Vector Machine'+'='*20)
print(cr_svm)
print('='*20+'Descion Tree'+'='*20)
print(cr_dt)
print('='*20+'Random Forest'+'='*20)
print(cr_rf)
print('='*20+'Multinomial NB'+'='*20)
print(cr_nb)
# Out:
# ====================Logistic Regression====================
#              precision    recall  f1-score   support
#
#           0       0.25      0.14      0.18        63
#           1       0.36      0.35      0.36       152
#           2       0.14      0.16      0.15        92
#           3       0.40      0.43      0.41       150
#           4       0.36      0.41      0.38        69
#
# avg / total       0.32      0.32      0.32       526
#
# ====================KNearest Neighbour====================
#              precision    recall  f1-score   support
#
#           0       0.18      0.10      0.12        63
#           1       0.29      0.65      0.40       152
#           2       0.19      0.27      0.22        92
#           3       0.43      0.04      0.07       150
#           4       0.18      0.03      0.05        69
#
# avg / total       0.29      0.26      0.20       526
#
# ====================Support Vector Machine====================
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        63
#           1       0.00      0.00      0.00       152
#           2       0.00      0.00      0.00        92
#           3       0.29      1.00      0.44       150
#           4       0.00      0.00      0.00        69
#
# avg / total       0.08      0.29      0.13       526
#
# ====================Descion Tree====================
#              precision    recall  f1-score   support
#
#           0       0.23      0.13      0.16        63
#           1       0.35      0.40      0.38       152
#           2       0.17      0.14      0.15        92
#           3       0.34      0.36      0.35       150
#           4       0.23      0.28      0.25        69
#
# avg / total       0.29      0.29      0.29       526
#
# ====================Random Forest====================
#              precision    recall  f1-score   support
#
#           0       0.36      0.13      0.19        63
#           1       0.37      0.52      0.43       152
#           2       0.22      0.17      0.19        92
#           3       0.41      0.45      0.43       150
#           4       0.41      0.30      0.35        69
#
# avg / total       0.36      0.37      0.35       526
#
# ====================Multinomial NB====================
#              precision    recall  f1-score   support
#
#           0       0.56      0.24      0.33        63
#           1       0.42      0.45      0.43       152
#           2       0.24      0.15      0.19        92
#           3       0.39      0.55      0.46       150
#           4       0.37      0.35      0.36        69
#
# avg / total       0.39      0.39      0.37       526

# %% [markdown]
# # Watson Machine Learning Deployment

# %% [markdown]
# ### Work with your WML instance<a id="work"></a>

# %% [markdown]
# First, you must import client libraries.

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient

# %%
wml_credentials = {
  "username": "be4e66c0-97f6-4274-87ea-5385e7141feb",
  "password": "a5fd994a-1228-4bea-ba5a-578667530b8c",
  "instance_id": "3cf5e26f-161f-4782-ae3e-1243aaa1ceff",
  "url": "https://ibm-watson-ml.eu-gb.bluemix.net"
}

# %% [markdown]
# #### Create the API client.

# %%
client = WatsonMachineLearningAPIClient(wml_credentials)

# %% [markdown]
# #### Get instance details.

# %%
import json

instance_details = client.service_instance.get_details()

# %% [markdown]
# ### 4.2 Save the model to the WML repository<a id="save"></a>

# %% [markdown]
# Define the model name, author name and email.

# %%
published_model = client.repository.store_model(model=model_nb, meta_props={'name':'Movie Review'}, \
                                                training_data=x_train, training_target=y_train)

# %% [markdown]
# #### Get information about a specific model in the WML repository.

# %%
published_model_uid = client.repository.get_model_uid(published_model)
model_details = client.repository.get_details(published_model_uid)

print(json.dumps(model_details, indent=2))
# Out:
# {
#   "metadata": {
#     "guid": "78359ac2-60f7-48f8-9bfb-dc986cde1667",
#     "modified_at": "2018-05-30T05:58:36.087Z",
#     "url": "https://ibm-watson-ml.eu-gb.bluemix.net/v3/wml_instances/3cf5e26f-161f-4782-ae3e-1243aaa1ceff/published_models/78359ac2-60f7-48f8-9bfb-dc986cde1667",
#     "created_at": "2018-05-30T05:58:35.946Z"
#   },
#   "entity": {
#     "feedback_url": "https://ibm-watson-ml.eu-gb.bluemix.net/v3/wml_instances/3cf5e26f-161f-4782-ae3e-1243aaa1ceff/published_models/78359ac2-60f7-48f8-9bfb-dc986cde1667/feedback",
#     "input_data_schema": {
#       "features": {
#         "type": "ndarray",
#         "fields": [
#           {
#             "name": "f0",
#             "type": "int"
#           },
#           {
#             "name": "f1",
#             "type": "int"
#           },
#           {
#             "name": "f2",
#             "type": "int"
#           },
#           {
#             "name": "f3",
#             "type": "int"
#           },
#           {
#             "name": "f4",
#             "type": "int"
#           },
#           {
#             "name": "f5",
#             "type": "int"
#           },
#           {
#             "name": "f6",
#             "type": "int"
#           },
#           {
#             "name": "f7",
#             "type": "int"
#           },
#           {
#             "name": "f8",
#             "type": "int"
#           },
#           {
#             "name": "f9",
#             "type": "int"
#           },
#           {
#             "name": "f10",
#             "type": "int"
#           },
#           {
#             "name": "f11",
#             "type": "int"
#           },
#           {
#             "name": "f12",
#             "type": "int"
#           },
#           {
#             "name": "f13",
#             "type": "int"
#           },
#           {
#             "name": "f14",
#             "type": "int"
#           },
#           {
#             "name": "f15",
#             "type": "int"
#           },
#           {
#             "name": "f16",
#             "type": "int"
#           },
#           {
#             "name": "f17",
#             "type": "int"
#           },
#           {
#             "name": "f18",
#             "type": "int"
#           },
#           {
#             "name": "f19",
#             "type": "int"
#           },
#           {
#             "name": "f20",
#             "type": "int"
#           },
#           {
#             "name": "f21",
#             "type": "int"
#           },
#           {
#             "name": "f22",
#             "type": "int"
#           },
#           {
#             "name": "f23",
#             "type": "int"
#           },
#           {
#             "name": "f24",
#             "type": "int"
#           },
#           {
#             "name": "f25",
#             "type": "int"
#           },
#           {
#             "name": "f26",
#             "type": "int"
#           },
#           {
#             "name": "f27",
#             "type": "int"
#           },
#           {
#             "name": "f28",
#             "type": "int"
#           },
#           {
#             "name": "f29",
#             "type": "int"
#           },
#           {
#             "name": "f30",
#             "type": "int"
#           },
#           {
#             "name": "f31",
#             "type": "int"
#           },
#           {
#             "name": "f32",
#             "type": "int"
#           },
#           {
#             "name": "f33",
#             "type": "int"
#           },
#           {
#             "name": "f34",
#             "type": "int"
#           },
#           {
#             "name": "f35",
#             "type": "int"
#           },
#           {
#             "name": "f36",
#             "type": "int"
#           },
#           {
#             "name": "f37",
#             "type": "int"
#           },
#           {
#             "name": "f38",
#             "type": "int"
#           },
#           {
#             "name": "f39",
#             "type": "int"
#           },
#           {
#             "name": "f40",
#             "type": "int"
#           },
#           {
#             "name": "f41",
#             "type": "int"
#           },
#           {
#             "name": "f42",
#             "type": "int"
#           },
#           {
#             "name": "f43",
#             "type": "int"
#           },
#           {
#             "name": "f44",
#             "type": "int"
#           },
#           {
#             "name": "f45",
#             "type": "int"
#           },
#           {
#             "name": "f46",
#             "type": "int"
#           },
#           {
#             "name": "f47",
#             "type": "int"
#           },
#           {
#             "name": "f48",
#             "type": "int"
#           },
#           {
#             "name": "f49",
#             "type": "int"
#           },
#           {
#             "name": "f50",
#             "type": "int"
#           },
#           {
#             "name": "f51",
#             "type": "int"
#           },
#           {
#             "name": "f52",
#             "type": "int"
#           },
#           {
#             "name": "f53",
#             "type": "int"
#           },
#           {
#             "name": "f54",
#             "type": "int"
#           },
#           {
#             "name": "f55",
#             "type": "int"
#           },
#           {
#             "name": "f56",
#             "type": "int"
#           },
#           {
#             "name": "f57",
#             "type": "int"
#           },
#           {
#             "name": "f58",
#             "type": "int"
#           },
#           {
#             "name": "f59",
#             "type": "int"
#           },
#           {
#             "name": "f60",
#             "type": "int"
#           },
#           {
#             "name": "f61",
#             "type": "int"
#           },
#           {
#             "name": "f62",
#             "type": "int"
#           },
#           {
#             "name": "f63",
#             "type": "int"
#           },
#           {
#             "name": "f64",
#             "type": "int"
#           },
#           {
#             "name": "f65",
#             "type": "int"
#           },
#           {
#             "name": "f66",
#             "type": "int"
#           },
#           {
#             "name": "f67",
#             "type": "int"
#           },
#           {
#             "name": "f68",
#             "type": "int"
#           },
#           {
#             "name": "f69",
#             "type": "int"
#           },
#           {
#             "name": "f70",
#             "type": "int"
#           },
#           {
#             "name": "f71",
#             "type": "int"
#           },
#           {
#             "name": "f72",
#             "type": "int"
#           },
#           {
#             "name": "f73",
#             "type": "int"
#           },
#           {
#             "name": "f74",
#             "type": "int"
#           },
#           {
#             "name": "f75",
#             "type": "int"
#           },
#           {
#             "name": "f76",
#             "type": "int"
#           },
#           {
#             "name": "f77",
#             "type": "int"
#           },
#           {
#             "name": "f78",
#             "type": "int"
#           },
#           {
#             "name": "f79",
#             "type": "int"
#           },
#           {
#             "name": "f80",
#             "type": "int"
#           },
#           {
#             "name": "f81",
#             "type": "int"
#           },
#           {
#             "name": "f82",
#             "type": "int"
#           },
#           {
#             "name": "f83",
#             "type": "int"
#           },
#           {
#             "name": "f84",
#             "type": "int"
#           },
#           {
#             "name": "f85",
#             "type": "int"
#           },
#           {
#             "name": "f86",
#             "type": "int"
#           },
#           {
#             "name": "f87",
#             "type": "int"
#           },
#           {
#             "name": "f88",
#             "type": "int"
#           },
#           {
#             "name": "f89",
#             "type": "int"
#           },
#           {
#             "name": "f90",
#             "type": "int"
#           },
#           {
#             "name": "f91",
#             "type": "int"
#           },
#           {
#             "name": "f92",
#             "type": "int"
#           },
#           {
#             "name": "f93",
#             "type": "int"
#           },
#           {
#             "name": "f94",
#             "type": "int"
#           },
#           {
#             "name": "f95",
#             "type": "int"
#           },
#           {
#             "name": "f96",
#             "type": "int"
#           },
#           {
#             "name": "f97",
#             "type": "int"
#           },
#           {
#             "name": "f98",
#             "type": "int"
#           },
#           {
#             "name": "f99",
#             "type": "int"
#           },
#           {
#             "name": "f100",
#             "type": "int"
#           },
#           {
#             "name": "f101",
#             "type": "int"
#           },
#           {
#             "name": "f102",
#             "type": "int"
#           },
#           {
#             "name": "f103",
#             "type": "int"
#           },
#           {
#             "name": "f104",
#             "type": "int"
#           },
#           {
#             "name": "f105",
#             "type": "int"
#           },
#           {
#             "name": "f106",
#             "type": "int"
#           },
#           {
#             "name": "f107",
#             "type": "int"
#           },
#           {
#             "name": "f108",
#             "type": "int"
#           },
#           {
#             "name": "f109",
#             "type": "int"
#           },
#           {
#             "name": "f110",
#             "type": "int"
#           },
#           {
#             "name": "f111",
#             "type": "int"
#           },
#           {
#             "name": "f112",
#             "type": "int"
#           },
#           {
#             "name": "f113",
#             "type": "int"
#           },
#           {
#             "name": "f114",
#             "type": "int"
#           },
#           {
#             "name": "f115",
#             "type": "int"
#           },
#           {
#             "name": "f116",
#             "type": "int"
#           },
#           {
#             "name": "f117",
#             "type": "int"
#           },
#           {
#             "name": "f118",
#             "type": "int"
#           },
#           {
#             "name": "f119",
#             "type": "int"
#           },
#           {
#             "name": "f120",
#             "type": "int"
#           },
#           {
#             "name": "f121",
#             "type": "int"
#           },
#           {
#             "name": "f122",
#             "type": "int"
#           },
#           {
#             "name": "f123",
#             "type": "int"
#           },
#           {
#             "name": "f124",
#             "type": "int"
#           },
#           {
#             "name": "f125",
#             "type": "int"
#           },
#           {
#             "name": "f126",
#             "type": "int"
#           },
#           {
#             "name": "f127",
#             "type": "int"
#           },
#           {
#             "name": "f128",
#             "type": "int"
#           },
#           {
#             "name": "f129",
#             "type": "int"
#           },
#           {
#             "name": "f130",
#             "type": "int"
#           },
#           {
#             "name": "f131",
#             "type": "int"
#           },
#           {
#             "name": "f132",
#             "type": "int"
#           },
#           {
#             "name": "f133",
#             "type": "int"
#           },
#           {
#             "name": "f134",
#             "type": "int"
#           },
#           {
#             "name": "f135",
#             "type": "int"
#           },
#           {
#             "name": "f136",
#             "type": "int"
#           },
#           {
#             "name": "f137",
#             "type": "int"
#           },
#           {
#             "name": "f138",
#             "type": "int"
#           },
#           {
#             "name": "f139",
#             "type": "int"
#           },
#           {
#             "name": "f140",
#             "type": "int"
#           },
#           {
#             "name": "f141",
#             "type": "int"
#           },
#           {
#             "name": "f142",
#             "type": "int"
#           },
#           {
#             "name": "f143",
#             "type": "int"
#           },
#           {
#             "name": "f144",
#             "type": "int"
#           },
#           {
#             "name": "f145",
#             "type": "int"
#           },
#           {
#             "name": "f146",
#             "type": "int"
#           },
#           {
#             "name": "f147",
#             "type": "int"
#           },
#           {
#             "name": "f148",
#             "type": "int"
#           },
#           {
#             "name": "f149",
#             "type": "int"
#           },
#           {
#             "name": "f150",
#             "type": "int"
#           },
#           {
#             "name": "f151",
#             "type": "int"
#           },
#           {
#             "name": "f152",
#             "type": "int"
#           },
#           {
#             "name": "f153",
#             "type": "int"
#           },
#           {
#             "name": "f154",
#             "type": "int"
#           },
#           {
#             "name": "f155",
#             "type": "int"
#           },
#           {
#             "name": "f156",
#             "type": "int"
#           },
#           {
#             "name": "f157",
#             "type": "int"
#           },
#           {
#             "name": "f158",
#             "type": "int"
#           },
#           {
#             "name": "f159",
#             "type": "int"
#           },
#           {
#             "name": "f160",
#             "type": "int"
#           },
#           {
#             "name": "f161",
#             "type": "int"
#           },
#           {
#             "name": "f162",
#             "type": "int"
#           },
#           {
#             "name": "f163",
#             "type": "int"
#           },
#           {
#             "name": "f164",
#             "type": "int"
#           },
#           {
#             "name": "f165",
#             "type": "int"
#           },
#           {
#             "name": "f166",
#             "type": "int"
#           },
#           {
#             "name": "f167",
#             "type": "int"
#           },
#           {
#             "name": "f168",
#             "type": "int"
#           },
#           {
#             "name": "f169",
#             "type": "int"
#           },
#           {
#             "name": "f170",
#             "type": "int"
#           },
#           {
#             "name": "f171",
#             "type": "int"
#           },
#           {
#             "name": "f172",
#             "type": "int"
#           },
#           {
#             "name": "f173",
#             "type": "int"
#           },
#           {
#             "name": "f174",
#             "type": "int"
#           },
#           {
#             "name": "f175",
#             "type": "int"
#           },
#           {
#             "name": "f176",
#             "type": "int"
#           },
#           {
#             "name": "f177",
#             "type": "int"
#           },
#           {
#             "name": "f178",
#             "type": "int"
#           },
#           {
#             "name": "f179",
#             "type": "int"
#           },
#           {
#             "name": "f180",
#             "type": "int"
#           },
#           {
#             "name": "f181",
#             "type": "int"
#           },
#           {
#             "name": "f182",
#             "type": "int"
#           },
#           {
#             "name": "f183",
#             "type": "int"
#           },
#           {
#             "name": "f184",
#             "type": "int"
#           },
#           {
#             "name": "f185",
#             "type": "int"
#           },
#           {
#             "name": "f186",
#             "type": "int"
#           },
#           {
#             "name": "f187",
#             "type": "int"
#           },
#           {
#             "name": "f188",
#             "type": "int"
#           },
#           {
#             "name": "f189",
#             "type": "int"
#           },
#           {
#             "name": "f190",
#             "type": "int"
#           },
#           {
#             "name": "f191",
#             "type": "int"
#           },
#           {
#             "name": "f192",
#             "type": "int"
#           },
#           {
#             "name": "f193",
#             "type": "int"
#           },
#           {
#             "name": "f194",
#             "type": "int"
#           },
#           {
#             "name": "f195",
#             "type": "int"
#           },
#           {
#             "name": "f196",
#             "type": "int"
#           },
#           {
#             "name": "f197",
#             "type": "int"
#           },
#           {
#             "name": "f198",
#             "type": "int"
#           },
#           {
#             "name": "f199",
#             "type": "int"
#           },
#           {
#             "name": "f200",
#             "type": "int"
#           },
#           {
#             "name": "f201",
#             "type": "int"
#           },
#           {
#             "name": "f202",
#             "type": "int"
#           },
#           {
#             "name": "f203",
#             "type": "int"
#           },
#           {
#             "name": "f204",
#             "type": "int"
#           },
#           {
#             "name": "f205",
#             "type": "int"
#           },
#           {
#             "name": "f206",
#             "type": "int"
#           },
#           {
#             "name": "f207",
#             "type": "int"
#           },
#           {
#             "name": "f208",
#             "type": "int"
#           },
#           {
#             "name": "f209",
#             "type": "int"
#           },
#           {
#             "name": "f210",
#             "type": "int"
#           },
#           {
#             "name": "f211",
#             "type": "int"
#           },
#           {
#             "name": "f212",
#             "type": "int"
#           },
#           {
#             "name": "f213",
#             "type": "int"
#           },
#           {
#             "name": "f214",
#             "type": "int"
#           },
#           {
#             "name": "f215",
#             "type": "int"
#           },
#           {
#             "name": "f216",
#             "type": "int"
#           },
#           {
#             "name": "f217",
#             "type": "int"
#           },
#           {
#             "name": "f218",
#             "type": "int"
#           },
#           {
#             "name": "f219",
#             "type": "int"
#           },
#           {
#             "name": "f220",
#             "type": "int"
#           },
#           {
#             "name": "f221",
#             "type": "int"
#           },
#           {
#             "name": "f222",
#             "type": "int"
#           },
#           {
#             "name": "f223",
#             "type": "int"
#           },
#           {
#             "name": "f224",
#             "type": "int"
#           },
#           {
#             "name": "f225",
#             "type": "int"
#           },
#           {
#             "name": "f226",
#             "type": "int"
#           },
#           {
#             "name": "f227",
#             "type": "int"
#           },
#           {
#             "name": "f228",
#             "type": "int"
#           },
#           {
#             "name": "f229",
#             "type": "int"
#           },
#           {
#             "name": "f230",
#             "type": "int"
#           },
#           {
#             "name": "f231",
#             "type": "int"
#           },
#           {
#             "name": "f232",
#             "type": "int"
#           },
#           {
#             "name": "f233",
#             "type": "int"
#           },
#           {
#             "name": "f234",
#             "type": "int"
#           },
#           {
#             "name": "f235",
#             "type": "int"
#           },
#           {
#             "name": "f236",
#             "type": "int"
#           },
#           {
#             "name": "f237",
#             "type": "int"
#           },
#           {
#             "name": "f238",
#             "type": "int"
#           },
#           {
#             "name": "f239",
#             "type": "int"
#           },
#           {
#             "name": "f240",
#             "type": "int"
#           },
#           {
#             "name": "f241",
#             "type": "int"
#           },
#           {
#             "name": "f242",
#             "type": "int"
#           },
#           {
#             "name": "f243",
#             "type": "int"
#           },
#           {
#             "name": "f244",
#             "type": "int"
#           },
#           {
#             "name": "f245",
#             "type": "int"
#           },
#           {
#             "name": "f246",
#             "type": "int"
#           },
#           {
#             "name": "f247",
#             "type": "int"
#           },
#           {
#             "name": "f248",
#             "type": "int"
#           },
#           {
#             "name": "f249",
#             "type": "int"
#           },
#           {
#             "name": "f250",
#             "type": "int"
#           },
#           {
#             "name": "f251",
#             "type": "int"
#           },
#           {
#             "name": "f252",
#             "type": "int"
#           },
#           {
#             "name": "f253",
#             "type": "int"
#           },
#           {
#             "name": "f254",
#             "type": "int"
#           },
#           {
#             "name": "f255",
#             "type": "int"
#           },
#           {
#             "name": "f256",
#             "type": "int"
#           },
#           {
#             "name": "f257",
#             "type": "int"
#           },
#           {
#             "name": "f258",
#             "type": "int"
#           },
#           {
#             "name": "f259",
#             "type": "int"
#           },
#           {
#             "name": "f260",
#             "type": "int"
#           },
#           {
#             "name": "f261",
#             "type": "int"
#           },
#           {
#             "name": "f262",
#             "type": "int"
#           },
#           {
#             "name": "f263",
#             "type": "int"
#           },
#           {
#             "name": "f264",
#             "type": "int"
#           },
#           {
#             "name": "f265",
#             "type": "int"
#           },
#           {
#             "name": "f266",
#             "type": "int"
#           },
#           {
#             "name": "f267",
#             "type": "int"
#           },
#           {
#             "name": "f268",
#             "type": "int"
#           },
#           {
#             "name": "f269",
#             "type": "int"
#           },
#           {
#             "name": "f270",
#             "type": "int"
#           },
#           {
#             "name": "f271",
#             "type": "int"
#           },
#           {
#             "name": "f272",
#             "type": "int"
#           },
#           {
#             "name": "f273",
#             "type": "int"
#           },
#           {
#             "name": "f274",
#             "type": "int"
#           },
#           {
#             "name": "f275",
#             "type": "int"
#           },
#           {
#             "name": "f276",
#             "type": "int"
#           },
#           {
#             "name": "f277",
#             "type": "int"
#           },
#           {
#             "name": "f278",
#             "type": "int"
#           },
#           {
#             "name": "f279",
#             "type": "int"
#           },
#           {
#             "name": "f280",
#             "type": "int"
#           },
#           {
#             "name": "f281",
#             "type": "int"
#           },
#           {
#             "name": "f282",
#             "type": "int"
#           },
#           {
#             "name": "f283",
#             "type": "int"
#           },
#           {
#             "name": "f284",
#             "type": "int"
#           },
#           {
#             "name": "f285",
#             "type": "int"
#           },
#           {
#             "name": "f286",
#             "type": "int"
#           },
#           {
#             "name": "f287",
#             "type": "int"
#           },
#           {
#             "name": "f288",
#             "type": "int"
#           },
#           {
#             "name": "f289",
#             "type": "int"
#           },
#           {
#             "name": "f290",
#             "type": "int"
#           },
#           {
#             "name": "f291",
#             "type": "int"
#           },
#           {
#             "name": "f292",
#             "type": "int"
#           },
#           {
#             "name": "f293",
#             "type": "int"
#           },
#           {
#             "name": "f294",
#             "type": "int"
#           },
#           {
#             "name": "f295",
#             "type": "int"
#           },
#           {
#             "name": "f296",
#             "type": "int"
#           },
#           {
#             "name": "f297",
#             "type": "int"
#           },
#           {
#             "name": "f298",
#             "type": "int"
#           },
#           {
#             "name": "f299",
#             "type": "int"
#           },
#           {
#             "name": "f300",
#             "type": "int"
#           },
#           {
#             "name": "f301",
#             "type": "int"
#           },
#           {
#             "name": "f302",
#             "type": "int"
#           },
#           {
#             "name": "f303",
#             "type": "int"
#           },
#           {
#             "name": "f304",
#             "type": "int"
#           },
#           {
#             "name": "f305",
#             "type": "int"
#           },
#           {
#             "name": "f306",
#             "type": "int"
#           },
#           {
#             "name": "f307",
#             "type": "int"
#           },
#           {
#             "name": "f308",
#             "type": "int"
#           },
#           {
#             "name": "f309",
#             "type": "int"
#           },
#           {
#             "name": "f310",
#             "type": "int"
#           },
#           {
#             "name": "f311",
#             "type": "int"
#           },
#           {
#             "name": "f312",
#             "type": "int"
#           },
#           {
#             "name": "f313",
#             "type": "int"
#           },
#           {
#             "name": "f314",
#             "type": "int"
#           },
#           {
#             "name": "f315",
#             "type": "int"
#           },
#           {
#             "name": "f316",
#             "type": "int"
#           },
#           {
#             "name": "f317",
#             "type": "int"
#           },
#           {
#             "name": "f318",
#             "type": "int"
#           },
#           {
#             "name": "f319",
#             "type": "int"
#           },
#           {
#             "name": "f320",
#             "type": "int"
#           },
#           {
#             "name": "f321",
#             "type": "int"
#           },
#           {
#             "name": "f322",
#             "type": "int"
#           },
#           {
#             "name": "f323",
#             "type": "int"
#           },
#           {
#             "name": "f324",
#             "type": "int"
#           },
#           {
#             "name": "f325",
#             "type": "int"
#           },
#           {
#             "name": "f326",
#             "type": "int"
#           },
#           {
#             "name": "f327",
#             "type": "int"
#           },
#           {
#             "name": "f328",
#             "type": "int"
#           },
#           {
#             "name": "f329",
#             "type": "int"
#           },
#           {
#             "name": "f330",
#             "type": "int"
#           },
#           {
#             "name": "f331",
#             "type": "int"
#           },
#           {
#             "name": "f332",
#             "type": "int"
#           },
#           {
#             "name": "f333",
#             "type": "int"
#           },
#           {
#             "name": "f334",
#             "type": "int"
#           },
#           {
#             "name": "f335",
#             "type": "int"
#           },
#           {
#             "name": "f336",
#             "type": "int"
#           },
#           {
#             "name": "f337",
#             "type": "int"
#           },
#           {
#             "name": "f338",
#             "type": "int"
#           },
#           {
#             "name": "f339",
#             "type": "int"
#           },
#           {
#             "name": "f340",
#             "type": "int"
#           },
#           {
#             "name": "f341",
#             "type": "int"
#           },
#           {
#             "name": "f342",
#             "type": "int"
#           },
#           {
#             "name": "f343",
#             "type": "int"
#           },
#           {
#             "name": "f344",
#             "type": "int"
#           },
#           {
#             "name": "f345",
#             "type": "int"
#           },
#           {
#             "name": "f346",
#             "type": "int"
#           },
#           {
#             "name": "f347",
#             "type": "int"
#           },
#           {
#             "name": "f348",
#             "type": "int"
#           },
#           {
#             "name": "f349",
#             "type": "int"
#           },
#           {
#             "name": "f350",
#             "type": "int"
#           },
#           {
#             "name": "f351",
#             "type": "int"
#           },
#           {
#             "name": "f352",
#             "type": "int"
#           },
#           {
#             "name": "f353",
#             "type": "int"
#           },
#           {
#             "name": "f354",
#             "type": "int"
#           },
#           {
#             "name": "f355",
#             "type": "int"
#           },
#           {
#             "name": "f356",
#             "type": "int"
#           },
#           {
#             "name": "f357",
#             "type": "int"
#           },
#           {
#             "name": "f358",
#             "type": "int"
#           },
#           {
#             "name": "f359",
#             "type": "int"
#           },
#           {
#             "name": "f360",
#             "type": "int"
#           },
#           {
#             "name": "f361",
#             "type": "int"
#           },
#           {
#             "name": "f362",
#             "type": "int"
#           },
#           {
#             "name": "f363",
#             "type": "int"
#           },
#           {
#             "name": "f364",
#             "type": "int"
#           },
#           {
#             "name": "f365",
#             "type": "int"
#           },
#           {
#             "name": "f366",
#             "type": "int"
#           },
#           {
#             "name": "f367",
#             "type": "int"
#           },
#           {
#             "name": "f368",
#             "type": "int"
#           },
#           {
#             "name": "f369",
#             "type": "int"
#           },
#           {
#             "name": "f370",
#             "type": "int"
#           },
#           {
#             "name": "f371",
#             "type": "int"
#           },
#           {
#             "name": "f372",
#             "type": "int"
#           },
#           {
#             "name": "f373",
#             "type": "int"
#           },
#           {
#             "name": "f374",
#             "type": "int"
#           },
#           {
#             "name": "f375",
#             "type": "int"
#           },
#           {
#             "name": "f376",
#             "type": "int"
#           },
#           {
#             "name": "f377",
#             "type": "int"
#           },
#           {
#             "name": "f378",
#             "type": "int"
#           },
#           {
#             "name": "f379",
#             "type": "int"
#           },
#           {
#             "name": "f380",
#             "type": "int"
#           },
#           {
#             "name": "f381",
#             "type": "int"
#           },
#           {
#             "name": "f382",
#             "type": "int"
#           },
#           {
#             "name": "f383",
#             "type": "int"
#           },
#           {
#             "name": "f384",
#             "type": "int"
#           },
#           {
#             "name": "f385",
#             "type": "int"
#           },
#           {
#             "name": "f386",
#             "type": "int"
#           },
#           {
#             "name": "f387",
#             "type": "int"
#           },
#           {
#             "name": "f388",
#             "type": "int"
#           },
#           {
#             "name": "f389",
#             "type": "int"
#           },
#           {
#             "name": "f390",
#             "type": "int"
#           },
#           {
#             "name": "f391",
#             "type": "int"
#           },
#           {
#             "name": "f392",
#             "type": "int"
#           },
#           {
#             "name": "f393",
#             "type": "int"
#           },
#           {
#             "name": "f394",
#             "type": "int"
#           },
#           {
#             "name": "f395",
#             "type": "int"
#           },
#           {
#             "name": "f396",
#             "type": "int"
#           },
#           {
#             "name": "f397",
#             "type": "int"
#           },
#           {
#             "name": "f398",
#             "type": "int"
#           },
#           {
#             "name": "f399",
#             "type": "int"
#           },
#           {
#             "name": "f400",
#             "type": "int"
#           },
#           {
#             "name": "f401",
#             "type": "int"
#           },
#           {
#             "name": "f402",
#             "type": "int"
#           },
#           {
#             "name": "f403",
#             "type": "int"
#           },
#           {
#             "name": "f404",
#             "type": "int"
#           },
#           {
#             "name": "f405",
#             "type": "int"
#           },
#           {
#             "name": "f406",
#             "type": "int"
#           },
#           {
#             "name": "f407",
#             "type": "int"
#           },
#           {
#             "name": "f408",
#             "type": "int"
#           },
#           {
#             "name": "f409",
#             "type": "int"
#           },
#           {
#             "name": "f410",
#             "type": "int"
#           },
#           {
#             "name": "f411",
#             "type": "int"
#           },
#           {
#             "name": "f412",
#             "type": "int"
#           },
#           {
#             "name": "f413",
#             "type": "int"
#           },
#           {
#             "name": "f414",
#             "type": "int"
#           },
#           {
#             "name": "f415",
#             "type": "int"
#           },
#           {
#             "name": "f416",
#             "type": "int"
#           },
#           {
#             "name": "f417",
#             "type": "int"
#           },
#           {
#             "name": "f418",
#             "type": "int"
#           },
#           {
#             "name": "f419",
#             "type": "int"
#           },
#           {
#             "name": "f420",
#             "type": "int"
#           },
#           {
#             "name": "f421",
#             "type": "int"
#           },
#           {
#             "name": "f422",
#             "type": "int"
#           },
#           {
#             "name": "f423",
#             "type": "int"
#           },
#           {
#             "name": "f424",
#             "type": "int"
#           },
#           {
#             "name": "f425",
#             "type": "int"
#           },
#           {
#             "name": "f426",
#             "type": "int"
#           },
#           {
#             "name": "f427",
#             "type": "int"
#           },
#           {
#             "name": "f428",
#             "type": "int"
#           },
#           {
#             "name": "f429",
#             "type": "int"
#           },
#           {
#             "name": "f430",
#             "type": "int"
#           },
#           {
#             "name": "f431",
#             "type": "int"
#           },
#           {
#             "name": "f432",
#             "type": "int"
#           },
#           {
#             "name": "f433",
#             "type": "int"
#           },
#           {
#             "name": "f434",
#             "type": "int"
#           },
#           {
#             "name": "f435",
#             "type": "int"
#           },
#           {
#             "name": "f436",
#             "type": "int"
#           },
#           {
#             "name": "f437",
#             "type": "int"
#           },
#           {
#             "name": "f438",
#             "type": "int"
#           },
#           {
#             "name": "f439",
#             "type": "int"
#           },
#           {
#             "name": "f440",
#             "type": "int"
#           },
#           {
#             "name": "f441",
#             "type": "int"
#           },
#           {
#             "name": "f442",
#             "type": "int"
#           },
#           {
#             "name": "f443",
#             "type": "int"
#           },
#           {
#             "name": "f444",
#             "type": "int"
#           },
#           {
#             "name": "f445",
#             "type": "int"
#           },
#           {
#             "name": "f446",
#             "type": "int"
#           },
#           {
#             "name": "f447",
#             "type": "int"
#           },
#           {
#             "name": "f448",
#             "type": "int"
#           },
#           {
#             "name": "f449",
#             "type": "int"
#           },
#           {
#             "name": "f450",
#             "type": "int"
#           },
#           {
#             "name": "f451",
#             "type": "int"
#           },
#           {
#             "name": "f452",
#             "type": "int"
#           },
#           {
#             "name": "f453",
#             "type": "int"
#           },
#           {
#             "name": "f454",
#             "type": "int"
#           },
#           {
#             "name": "f455",
#             "type": "int"
#           },
#           {
#             "name": "f456",
#             "type": "int"
#           },
#           {
#             "name": "f457",
#             "type": "int"
#           },
#           {
#             "name": "f458",
#             "type": "int"
#           },
#           {
#             "name": "f459",
#             "type": "int"
#           },
#           {
#             "name": "f460",
#             "type": "int"
#           },
#           {
#             "name": "f461",
#             "type": "int"
#           },
#           {
#             "name": "f462",
#             "type": "int"
#           },
#           {
#             "name": "f463",
#             "type": "int"
#           },
#           {
#             "name": "f464",
#             "type": "int"
#           },
#           {
#             "name": "f465",
#             "type": "int"
#           },
#           {
#             "name": "f466",
#             "type": "int"
#           },
#           {
#             "name": "f467",
#             "type": "int"
#           },
#           {
#             "name": "f468",
#             "type": "int"
#           },
#           {
#             "name": "f469",
#             "type": "int"
#           },
#           {
#             "name": "f470",
#             "type": "int"
#           },
#           {
#             "name": "f471",
#             "type": "int"
#           },
#           {
#             "name": "f472",
#             "type": "int"
#           },
#           {
#             "name": "f473",
#             "type": "int"
#           },
#           {
#             "name": "f474",
#             "type": "int"
#           },
#           {
#             "name": "f475",
#             "type": "int"
#           },
#           {
#             "name": "f476",
#             "type": "int"
#           },
#           {
#             "name": "f477",
#             "type": "int"
#           },
#           {
#             "name": "f478",
#             "type": "int"
#           },
#           {
#             "name": "f479",
#             "type": "int"
#           },
#           {
#             "name": "f480",
#             "type": "int"
#           },
#           {
#             "name": "f481",
#             "type": "int"
#           },
#           {
#             "name": "f482",
#             "type": "int"
#           },
#           {
#             "name": "f483",
#             "type": "int"
#           },
#           {
#             "name": "f484",
#             "type": "int"
#           },
#           {
#             "name": "f485",
#             "type": "int"
#           },
#           {
#             "name": "f486",
#             "type": "int"
#           },
#           {
#             "name": "f487",
#             "type": "int"
#           },
#           {
#             "name": "f488",
#             "type": "int"
#           },
#           {
#             "name": "f489",
#             "type": "int"
#           },
#           {
#             "name": "f490",
#             "type": "int"
#           },
#           {
#             "name": "f491",
#             "type": "int"
#           },
#           {
#             "name": "f492",
#             "type": "int"
#           },
#           {
#             "name": "f493",
#             "type": "int"
#           },
#           {
#             "name": "f494",
#             "type": "int"
#           },
#           {
#             "name": "f495",
#             "type": "int"
#           },
#           {
#             "name": "f496",
#             "type": "int"
#           },
#           {
#             "name": "f497",
#             "type": "int"
#           },
#           {
#             "name": "f498",
#             "type": "int"
#           },
#           {
#             "name": "f499",
#             "type": "int"
#           },
#           {
#             "name": "f500",
#             "type": "int"
#           },
#           {
#             "name": "f501",
#             "type": "int"
#           },
#           {
#             "name": "f502",
#             "type": "int"
#           },
#           {
#             "name": "f503",
#             "type": "int"
#           },
#           {
#             "name": "f504",
#             "type": "int"
#           },
#           {
#             "name": "f505",
#             "type": "int"
#           },
#           {
#             "name": "f506",
#             "type": "int"
#           },
#           {
#             "name": "f507",
#             "type": "int"
#           },
#           {
#             "name": "f508",
#             "type": "int"
#           },
#           {
#             "name": "f509",
#             "type": "int"
#           },
#           {
#             "name": "f510",
#             "type": "int"
#           },
#           {
#             "name": "f511",
#             "type": "int"
#           },
#           {
#             "name": "f512",
#             "type": "int"
#           },
#           {
#             "name": "f513",
#             "type": "int"
#           },
#           {
#             "name": "f514",
#             "type": "int"
#           },
#           {
#             "name": "f515",
#             "type": "int"
#           },
#           {
#             "name": "f516",
#             "type": "int"
#           },
#           {
#             "name": "f517",
#             "type": "int"
#           },
#           {
#             "name": "f518",
#             "type": "int"
#           },
#           {
#             "name": "f519",
#             "type": "int"
#           },
#           {
#             "name": "f520",
#             "type": "int"
#           },
#           {
#             "name": "f521",
#             "type": "int"
#           },
#           {
#             "name": "f522",
#             "type": "int"
#           },
#           {
#             "name": "f523",
#             "type": "int"
#           },
#           {
#             "name": "f524",
#             "type": "int"
#           },
#           {
#             "name": "f525",
#             "type": "int"
#           },
#           {
#             "name": "f526",
#             "type": "int"
#           },
#           {
#             "name": "f527",
#             "type": "int"
#           },
#           {
#             "name": "f528",
#             "type": "int"
#           },
#           {
#             "name": "f529",
#             "type": "int"
#           },
#           {
#             "name": "f530",
#             "type": "int"
#           },
#           {
#             "name": "f531",
#             "type": "int"
#           },
#           {
#             "name": "f532",
#             "type": "int"
#           },
#           {
#             "name": "f533",
#             "type": "int"
#           },
#           {
#             "name": "f534",
#             "type": "int"
#           },
#           {
#             "name": "f535",
#             "type": "int"
#           },
#           {
#             "name": "f536",
#             "type": "int"
#           },
#           {
#             "name": "f537",
#             "type": "int"
#           },
#           {
#             "name": "f538",
#             "type": "int"
#           },
#           {
#             "name": "f539",
#             "type": "int"
#           },
#           {
#             "name": "f540",
#             "type": "int"
#           },
#           {
#             "name": "f541",
#             "type": "int"
#           },
#           {
#             "name": "f542",
#             "type": "int"
#           },
#           {
#             "name": "f543",
#             "type": "int"
#           },
#           {
#             "name": "f544",
#             "type": "int"
#           },
#           {
#             "name": "f545",
#             "type": "int"
#           },
#           {
#             "name": "f546",
#             "type": "int"
#           },
#           {
#             "name": "f547",
#             "type": "int"
#           },
#           {
#             "name": "f548",
#             "type": "int"
#           },
#           {
#             "name": "f549",
#             "type": "int"
#           },
#           {
#             "name": "f550",
#             "type": "int"
#           },
#           {
#             "name": "f551",
#             "type": "int"
#           },
#           {
#             "name": "f552",
#             "type": "int"
#           },
#           {
#             "name": "f553",
#             "type": "int"
#           },
#           {
#             "name": "f554",
#             "type": "int"
#           },
#           {
#             "name": "f555",
#             "type": "int"
#           },
#           {
#             "name": "f556",
#             "type": "int"
#           },
#           {
#             "name": "f557",
#             "type": "int"
#           },
#           {
#             "name": "f558",
#             "type": "int"
#           },
#           {
#             "name": "f559",
#             "type": "int"
#           },
#           {
#             "name": "f560",
#             "type": "int"
#           },
#           {
#             "name": "f561",
#             "type": "int"
#           },
#           {
#             "name": "f562",
#             "type": "int"
#           },
#           {
#             "name": "f563",
#             "type": "int"
#           },
#           {
#             "name": "f564",
#             "type": "int"
#           },
#           {
#             "name": "f565",
#             "type": "int"
#           },
#           {
#             "name": "f566",
#             "type": "int"
#           },
#           {
#             "name": "f567",
#             "type": "int"
#           },
#           {
#             "name": "f568",
#             "type": "int"
#           },
#           {
#             "name": "f569",
#             "type": "int"
#           },
#           {
#             "name": "f570",
#             "type": "int"
#           },
#           {
#             "name": "f571",
#             "type": "int"
#           },
#           {
#             "name": "f572",
#             "type": "int"
#           },
#           {
#             "name": "f573",
#             "type": "int"
#           },
#           {
#             "name": "f574",
#             "type": "int"
#           },
#           {
#             "name": "f575",
#             "type": "int"
#           },
#           {
#             "name": "f576",
#             "type": "int"
#           },
#           {
#             "name": "f577",
#             "type": "int"
#           },
#           {
#             "name": "f578",
#             "type": "int"
#           },
#           {
#             "name": "f579",
#             "type": "int"
#           },
#           {
#             "name": "f580",
#             "type": "int"
#           },
#           {
#             "name": "f581",
#             "type": "int"
#           },
#           {
#             "name": "f582",
#             "type": "int"
#           },
#           {
#             "name": "f583",
#             "type": "int"
#           },
#           {
#             "name": "f584",
#             "type": "int"
#           },
#           {
#             "name": "f585",
#             "type": "int"
#           },
#           {
#             "name": "f586",
#             "type": "int"
#           },
#           {
#             "name": "f587",
#             "type": "int"
#           },
#           {
#             "name": "f588",
#             "type": "int"
#           },
#           {
#             "name": "f589",
#             "type": "int"
#           },
#           {
#             "name": "f590",
#             "type": "int"
#           },
#           {
#             "name": "f591",
#             "type": "int"
#           },
#           {
#             "name": "f592",
#             "type": "int"
#           },
#           {
#             "name": "f593",
#             "type": "int"
#           },
#           {
#             "name": "f594",
#             "type": "int"
#           },
#           {
#             "name": "f595",
#             "type": "int"
#           },
#           {
#             "name": "f596",
#             "type": "int"
#           },
#           {
#             "name": "f597",
#             "type": "int"
#           },
#           {
#             "name": "f598",
#             "type": "int"
#           },
#           {
#             "name": "f599",
#             "type": "int"
#           },
#           {
#             "name": "f600",
#             "type": "int"
#           },
#           {
# ...
#           },
#           {
#             "name": "f5885",
#             "type": "int"
#           },
#           {
#             "name": "f5886",
#             "type": "int"
#           },
#           {
#             "name": "f5887",
#             "type": "int"
#           },
#           {
#             "name": "f5888",
#             "type": "int"
#           },
#           {
#             "name": "f5889",
#             "type": "int"
#           },
#           {
#             "name": "f5890",
#             "type": "int"
#           },
#           {
#             "name": "f5891",
#             "type": "int"
#           },
#           {
#             "name": "f5892",
#             "type": "int"
#           },
#           {
#             "name": "f5893",
#             "type": "int"
#           },
#           {
#             "name": "f5894",
#             "type": "int"
#           },
#           {
#             "name": "f5895",
#             "type": "int"
#           },
#           {
#             "name": "f5896",
#             "type": "int"
#           },
#           {
#             "name": "f5897",
#             "type": "int"
#           },
#           {
#             "name": "f5898",
#             "type": "int"
#           },
#           {
#             "name": "f5899",
#             "type": "int"
#           },
#           {
#             "name": "f5900",
#             "type": "int"
#           },
#           {
#             "name": "f5901",
#             "type": "int"
#           },
#           {
#             "name": "f5902",
#             "type": "int"
#           },
#           {
#             "name": "f5903",
#             "type": "int"
#           },
#           {
#             "name": "f5904",
#             "type": "int"
#           },
#           {
#             "name": "f5905",
#             "type": "int"
#           },
#           {
#             "name": "f5906",
#             "type": "int"
#           },
#           {
#             "name": "f5907",
#             "type": "int"
#           },
#           {
#             "name": "f5908",
#             "type": "int"
#           },
#           {
#             "name": "f5909",
#             "type": "int"
#           },
#           {
#             "name": "f5910",
#             "type": "int"
#           },
#           {
#             "name": "f5911",
#             "type": "int"
#           },
#           {
#             "name": "f5912",
#             "type": "int"
#           },
#           {
#             "name": "f5913",
#             "type": "int"
#           },
#           {
#             "name": "f5914",
#             "type": "int"
#           },
#           {
#             "name": "f5915",
#             "type": "int"
#           },
#           {
#             "name": "f5916",
#             "type": "int"
#           },
#           {
#             "name": "f5917",
#             "type": "int"
#           },
#           {
#             "name": "f5918",
#             "type": "int"
#           },
#           {
#             "name": "f5919",
#             "type": "int"
#           },
#           {
#             "name": "f5920",
#             "type": "int"
#           },
#           {
#             "name": "f5921",
#             "type": "int"
#           },
#           {
#             "name": "f5922",
#             "type": "int"
#           },
#           {
#             "name": "f5923",
#             "type": "int"
#           },
#           {
#             "name": "f5924",
#             "type": "int"
#           },
#           {
#             "name": "f5925",
#             "type": "int"
#           },
#           {
#             "name": "f5926",
#             "type": "int"
#           },
#           {
#             "name": "f5927",
#             "type": "int"
#           },
#           {
#             "name": "f5928",
#             "type": "int"
#           },
#           {
#             "name": "f5929",
#             "type": "int"
#           },
#           {
#             "name": "f5930",
#             "type": "int"
#           },
#           {
#             "name": "f5931",
#             "type": "int"
#           },
#           {
#             "name": "f5932",
#             "type": "int"
#           },
#           {
#             "name": "f5933",
#             "type": "int"
#           },
#           {
#             "name": "f5934",
#             "type": "int"
#           },
#           {
#             "name": "f5935",
#             "type": "int"
#           },
#           {
#             "name": "f5936",
#             "type": "int"
#           },
#           {
#             "name": "f5937",
#             "type": "int"
#           },
#           {
#             "name": "f5938",
#             "type": "int"
#           },
#           {
#             "name": "f5939",
#             "type": "int"
#           },
#           {
#             "name": "f5940",
#             "type": "int"
#           },
#           {
#             "name": "f5941",
#             "type": "int"
#           },
#           {
#             "name": "f5942",
#             "type": "int"
#           },
#           {
#             "name": "f5943",
#             "type": "int"
#           },
#           {
#             "name": "f5944",
#             "type": "int"
#           },
#           {
#             "name": "f5945",
#             "type": "int"
#           },
#           {
#             "name": "f5946",
#             "type": "int"
#           },
#           {
#             "name": "f5947",
#             "type": "int"
#           },
#           {
#             "name": "f5948",
#             "type": "int"
#           },
#           {
#             "name": "f5949",
#             "type": "int"
#           },
#           {
#             "name": "f5950",
#             "type": "int"
#           },
#           {
#             "name": "f5951",
#             "type": "int"
#           },
#           {
#             "name": "f5952",
#             "type": "int"
#           },
#           {
#             "name": "f5953",
#             "type": "int"
#           },
#           {
#             "name": "f5954",
#             "type": "int"
#           },
#           {
#             "name": "f5955",
#             "type": "int"
#           },
#           {
#             "name": "f5956",
#             "type": "int"
#           },
#           {
#             "name": "f5957",
#             "type": "int"
#           },
#           {
#             "name": "f5958",
#             "type": "int"
#           },
#           {
#             "name": "f5959",
#             "type": "int"
#           },
#           {
#             "name": "f5960",
#             "type": "int"
#           },
#           {
#             "name": "f5961",
#             "type": "int"
#           },
#           {
#             "name": "f5962",
#             "type": "int"
#           },
#           {
#             "name": "f5963",
#             "type": "int"
#           },
#           {
#             "name": "f5964",
#             "type": "int"
#           },
#           {
#             "name": "f5965",
#             "type": "int"
#           },
#           {
#             "name": "f5966",
#             "type": "int"
#           },
#           {
#             "name": "f5967",
#             "type": "int"
#           },
#           {
#             "name": "f5968",
#             "type": "int"
#           },
#           {
#             "name": "f5969",
#             "type": "int"
#           },
#           {
#             "name": "f5970",
#             "type": "int"
#           },
#           {
#             "name": "f5971",
#             "type": "int"
#           },
#           {
#             "name": "f5972",
#             "type": "int"
#           },
#           {
#             "name": "f5973",
#             "type": "int"
#           },
#           {
#             "name": "f5974",
#             "type": "int"
#           },
#           {
#             "name": "f5975",
#             "type": "int"
#           },
#           {
#             "name": "f5976",
#             "type": "int"
#           },
#           {
#             "name": "f5977",
#             "type": "int"
#           },
#           {
#             "name": "f5978",
#             "type": "int"
#           },
#           {
#             "name": "f5979",
#             "type": "int"
#           },
#           {
#             "name": "f5980",
#             "type": "int"
#           },
#           {
#             "name": "f5981",
#             "type": "int"
#           },
#           {
#             "name": "f5982",
#             "type": "int"
#           },
#           {
#             "name": "f5983",
#             "type": "int"
#           },
#           {
#             "name": "f5984",
#             "type": "int"
#           },
#           {
#             "name": "f5985",
#             "type": "int"
#           },
#           {
#             "name": "f5986",
#             "type": "int"
#           },
#           {
#             "name": "f5987",
#             "type": "int"
#           },
#           {
#             "name": "f5988",
#             "type": "int"
#           },
#           {
#             "name": "f5989",
#             "type": "int"
#           },
#           {
#             "name": "f5990",
#             "type": "int"
#           },
#           {
#             "name": "f5991",
#             "type": "int"
#           },
#           {
#             "name": "f5992",
#             "type": "int"
#           },
#           {
#             "name": "f5993",
#             "type": "int"
#           },
#           {
#             "name": "f5994",
#             "type": "int"
#           },
#           {
#             "name": "f5995",
#             "type": "int"
#           },
#           {
#             "name": "f5996",
#             "type": "int"
#           },
#           {
#             "name": "f5997",
#             "type": "int"
#           },
#           {
#             "name": "f5998",
#             "type": "int"
#           },
#           {
#             "name": "f5999",
#             "type": "int"
#           },
#           {
#             "name": "f6000",
#             "type": "int"
#           },
#           {
#             "name": "f6001",
#             "type": "int"
#           },
#           {
#             "name": "f6002",
#             "type": "int"
#           },
#           {
#             "name": "f6003",
#             "type": "int"
#           },
#           {
#             "name": "f6004",
#             "type": "int"
#           },
#           {
#             "name": "f6005",
#             "type": "int"
#           },
#           {
#             "name": "f6006",
#             "type": "int"
#           },
#           {
#             "name": "f6007",
#             "type": "int"
#           },
#           {
#             "name": "f6008",
#             "type": "int"
#           },
#           {
#             "name": "f6009",
#             "type": "int"
#           },
#           {
#             "name": "f6010",
#             "type": "int"
#           },
#           {
#             "name": "f6011",
#             "type": "int"
#           },
#           {
#             "name": "f6012",
#             "type": "int"
#           },
#           {
#             "name": "f6013",
#             "type": "int"
#           },
#           {
#             "name": "f6014",
#             "type": "int"
#           },
#           {
#             "name": "f6015",
#             "type": "int"
#           },
#           {
#             "name": "f6016",
#             "type": "int"
#           },
#           {
#             "name": "f6017",
#             "type": "int"
#           },
#           {
#             "name": "f6018",
#             "type": "int"
#           },
#           {
#             "name": "f6019",
#             "type": "int"
#           },
#           {
#             "name": "f6020",
#             "type": "int"
#           },
#           {
#             "name": "f6021",
#             "type": "int"
#           },
#           {
#             "name": "f6022",
#             "type": "int"
#           },
#           {
#             "name": "f6023",
#             "type": "int"
#           },
#           {
#             "name": "f6024",
#             "type": "int"
#           },
#           {
#             "name": "f6025",
#             "type": "int"
#           },
#           {
#             "name": "f6026",
#             "type": "int"
#           },
#           {
#             "name": "f6027",
#             "type": "int"
#           },
#           {
#             "name": "f6028",
#             "type": "int"
#           },
#           {
#             "name": "f6029",
#             "type": "int"
#           },
#           {
#             "name": "f6030",
#             "type": "int"
#           },
#           {
#             "name": "f6031",
#             "type": "int"
#           },
#           {
#             "name": "f6032",
#             "type": "int"
#           },
#           {
#             "name": "f6033",
#             "type": "int"
#           },
#           {
#             "name": "f6034",
#             "type": "int"
#           },
#           {
#             "name": "f6035",
#             "type": "int"
#           },
#           {
#             "name": "f6036",
#             "type": "int"
#           },
#           {
#             "name": "f6037",
#             "type": "int"
#           },
#           {
#             "name": "f6038",
#             "type": "int"
#           },
#           {
#             "name": "f6039",
#             "type": "int"
#           },
#           {
#             "name": "f6040",
#             "type": "int"
#           },
#           {
#             "name": "f6041",
#             "type": "int"
#           },
#           {
#             "name": "f6042",
#             "type": "int"
#           },
#           {
#             "name": "f6043",
#             "type": "int"
#           },
#           {
#             "name": "f6044",
#             "type": "int"
#           },
#           {
#             "name": "f6045",
#             "type": "int"
#           },
#           {
#             "name": "f6046",
#             "type": "int"
#           },
#           {
#             "name": "f6047",
#             "type": "int"
#           },
#           {
#             "name": "f6048",
#             "type": "int"
#           },
#           {
#             "name": "f6049",
#             "type": "int"
#           },
#           {
#             "name": "f6050",
#             "type": "int"
#           },
#           {
#             "name": "f6051",
#             "type": "int"
#           },
#           {
#             "name": "f6052",
#             "type": "int"
#           },
#           {
#             "name": "f6053",
#             "type": "int"
#           },
#           {
#             "name": "f6054",
#             "type": "int"
#           },
#           {
#             "name": "f6055",
#             "type": "int"
#           },
#           {
#             "name": "f6056",
#             "type": "int"
#           },
#           {
#             "name": "f6057",
#             "type": "int"
#           },
#           {
#             "name": "f6058",
#             "type": "int"
#           },
#           {
#             "name": "f6059",
#             "type": "int"
#           },
#           {
#             "name": "f6060",
#             "type": "int"
#           },
#           {
#             "name": "f6061",
#             "type": "int"
#           },
#           {
#             "name": "f6062",
#             "type": "int"
#           },
#           {
#             "name": "f6063",
#             "type": "int"
#           },
#           {
#             "name": "f6064",
#             "type": "int"
#           },
#           {
#             "name": "f6065",
#             "type": "int"
#           },
#           {
#             "name": "f6066",
#             "type": "int"
#           },
#           {
#             "name": "f6067",
#             "type": "int"
#           },
#           {
#             "name": "f6068",
#             "type": "int"
#           },
#           {
#             "name": "f6069",
#             "type": "int"
#           },
#           {
#             "name": "f6070",
#             "type": "int"
#           },
#           {
#             "name": "f6071",
#             "type": "int"
#           },
#           {
#             "name": "f6072",
#             "type": "int"
#           },
#           {
#             "name": "f6073",
#             "type": "int"
#           },
#           {
#             "name": "f6074",
#             "type": "int"
#           },
#           {
#             "name": "f6075",
#             "type": "int"
#           },
#           {
#             "name": "f6076",
#             "type": "int"
#           },
#           {
#             "name": "f6077",
#             "type": "int"
#           }
#         ]
#       },
#       "labels": {
#         "type": "ndarray",
#         "fields": [
#           {
#             "name": "l1",
#             "type": "int"
#           }
#         ]
#       }
#     },
#     "name": "Movie Review",
#     "latest_version": {
#       "url": "https://ibm-watson-ml.eu-gb.bluemix.net/v3/ml_assets/models/78359ac2-60f7-48f8-9bfb-dc986cde1667/versions/4312823d-4a80-4d61-8831-6c2e0498865b",
#       "guid": "4312823d-4a80-4d61-8831-6c2e0498865b",
#       "created_at": "2018-05-30T05:58:36.087Z"
#     },
#     "label_col": "l1"
#   }
# }

# %% [markdown]
# #### Get information about all of the models in the WML repository.

# %%
models_details = client.repository.list_models()
# Out:
# ------------------------------------  -------------------  ------------------------  -----------------
# GUID                                  NAME                 CREATED                   FRAMEWORK
# bf5bf432-b8a0-46de-9a9e-877e124ae8f1  classification       2018-05-29T05:27:35.199Z  wml-1.1
# 6982543c-ac2f-4b1f-92e0-52a67490ca6d  Movie Review System  2018-05-30T02:29:02.774Z  scikit-learn-0.19
# 78359ac2-60f7-48f8-9bfb-dc986cde1667  Movie Review         2018-05-30T05:58:35.946Z  scikit-learn-0.19
# ------------------------------------  -------------------  ------------------------  -----------------

# %% [markdown]
# ### 4.3 Load a model from the WML repository<a id="load"></a>

# %% [markdown]
# In this subsection you will learn how to load a saved model from a specific WML instance.

# %%
loaded_model = client.repository.load(published_model_uid)

# %% [markdown]
# Make test predictions to check that the model has been loaded correctly.

# %%
test_predictions = loaded_model.predict(x_test[:5])

# %%
print(test_predictions)
# Out:
# [1 3 4 1 1]

# %% [markdown]
# As you can see you are able to make predictions, which means that the model has loaded correctly. You have now  learned how save to and load the model from the WML repository.

# %% [markdown]
# ### 4.4 Delete a model from the WML repository<a id="delete"></a>

# %% [markdown]
# The code in the following cell deletes a published model from the WML repository. The code is commented out at this stage because you still need the model for deployment.

# %%
# client.repository.delete(published_model_uid)

# %% [markdown]
# <a id="scoring"></a>
# ## 5. Deploy and score data in the IBM Cloud

# %% [markdown]
# ### 5.1 Create the online deployment for the published model<a id="create"></a>

# %%
created_deployment = client.deployments.create(published_model_uid, "Tomatameter")
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: 'b44b8b95-e742-43aa-b34e-0a2689a23704' started
#
# #######################################################################################
#
#
# INITIALIZING
# DEPLOY_SUCCESS
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='b44b8b95-e742-43aa-b34e-0a2689a23704'
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# **Note**: Here you use the deployment url saved in published_model object. The next section shows you how to retrieve the deployment url from WML instance.

# %% [markdown]
# Now you can define and print an online scoring endpoint.

# %%
scoring_endpoint = client.deployments.get_scoring_url(created_deployment)

print(scoring_endpoint)
# Out:
# https://ibm-watson-ml.eu-gb.bluemix.net/v3/wml_instances/3cf5e26f-161f-4782-ae3e-1243aaa1ceff/published_models/78359ac2-60f7-48f8-9bfb-dc986cde1667/deployments/b44b8b95-e742-43aa-b34e-0a2689a23704/online

# %% [markdown]
# ### 5.2 Get deployments<a id="getdeploy"></a>

# %%
deployments = client.deployments.get_details()

# %% [markdown]
# You can get the deployment_url by parsing the deployment details for the last deployed model.

# %%
deployment_url = client.deployments.get_url(created_deployment)

print(deployment_url)
# Out:
# https://ibm-watson-ml.eu-gb.bluemix.net/v3/wml_instances/3cf5e26f-161f-4782-ae3e-1243aaa1ceff/published_models/78359ac2-60f7-48f8-9bfb-dc986cde1667/deployments/b44b8b95-e742-43aa-b34e-0a2689a23704
